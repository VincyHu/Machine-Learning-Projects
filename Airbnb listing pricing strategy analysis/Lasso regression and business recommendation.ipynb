# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error
from gensim.models import Word2Vec, Phrases
pd.set_option('display.max_columns', 200)
sns.set()

# %%
listing = pd.read_csv('./listings.csv')
# Out:
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
listing.head(5)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20200212052255   2020-02-12
# 1  5858  https://www.airbnb.com/rooms/5858  20200212052255   2020-02-12
# 2  7918  https://www.airbnb.com/rooms/7918  20200212052255   2020-02-12
# 3  8142  https://www.airbnb.com/rooms/8142  20200212052255   2020-02-12
# 4  8339  https://www.airbnb.com/rooms/8339  20200212052255   2020-02-12
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                              summary  \
# 0  New update: the house next door is under const...
# 1                                                NaN
# 2  Nice and good public transportation.  7 minute...
# 3  Nice and good public transportation.  7 minute...
# 4  Pls email before booking.  Interior featured i...
#
#                                                space  \
# 0  Newly remodeled, modern, and bright garden uni...
# 1  We live in a large Victorian house on a quiet ...
# 2  Settle down, S.F. resident, student, hospital,...
# 3  Settle down, S.F. resident, student, hospital,...
# 4  Please send us a quick message before booking ...
#
#                                          description experiences_offered  \
# 0  New update: the house next door is under const...                none
# 1  We live in a large Victorian house on a quiet ...                none
# 2  Nice and good public transportation.  7 minute...                none
# 3  Nice and good public transportation.  7 minute...                none
# 4  Pls email before booking.  Interior featured i...                none
#
#                                neighborhood_overview  \
# 0  *Quiet cul de sac in friendly neighborhood *St...
# 1  I love how our neighborhood feels quiet but is...
# 2  Shopping old town, restaurants, McDonald, Whol...
# 3                                                NaN
# 4                                                NaN
#
#                                                notes  \
# 0  Due to the fact that we have children and a do...
# 1  All the furniture in the house was handmade so...
# 2  Wi-Fi signal in common areas.   Large eat in k...
# 3  Wi-Fi signal in common areas.   Large eat in k...
# 4                      tax ID on file tax ID on file
#
#                                              transit  \
# 0  *Public Transportation is 1/2 block away.  *Ce...
# 1  The train is two blocks away and you can stop ...
# 2         N Juda Muni and bus stop.  Street parking.
# 3  N Juda Muni, Bus and UCSF Shuttle. small shopp...
# 4                                                NaN
#
#                                               access  \
# 0  *Full access to patio and backyard (shared wit...
# 1  Our deck, garden, gourmet kitchen and extensiv...
# 2                                                NaN
# 3                                                NaN
# 4  Guests have access to everything listed and sh...
#
#                                          interaction  \
# 0  A family of 4 lives upstairs with their dog. N...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  * No Pets - even visiting guests for a short t...            NaN
# 1  Please respect the house, the art work, the fu...            NaN
# 2  No party, No smoking, not for any kinds of smo...            NaN
# 3       no pet no smoke no party inside the building            NaN
# 4  House Manual and House Rules will be provided ...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/b7c2a199-4...
# 1         NaN  https://a0.muscache.com/im/pictures/17714/3a7a...
# 2         NaN  https://a0.muscache.com/im/pictures/26356/8030...
# 3         NaN  https://a0.muscache.com/im/pictures/27832/3b1f...
# 4         NaN  https://a0.muscache.com/im/pictures/213fbf05-3...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN     1169   https://www.airbnb.com/users/show/1169
# 1             NaN     8904   https://www.airbnb.com/users/show/8904
# 2             NaN    21994  https://www.airbnb.com/users/show/21994
# 3             NaN    21994  https://www.airbnb.com/users/show/21994
# 4             NaN    24215  https://www.airbnb.com/users/show/24215
#
#           host_name  host_since                             host_location  \
# 0             Holly  2008-07-31  San Francisco, California, United States
# 1  Philip And Tania  2009-03-02  San Francisco, California, United States
# 2             Aaron  2009-06-17  San Francisco, California, United States
# 3             Aaron  2009-06-17  San Francisco, California, United States
# 4              Rosy  2009-07-02  San Francisco, California, United States
#
#                                           host_about  host_response_time  \
# 0  We are a family with 2 boys born in 2009 and 2...      within an hour
# 1  Philip: English transplant to the Bay Area and...        within a day
# 2  7 minutes walk to UCSF hospital & school campu...      within an hour
# 3  7 minutes walk to UCSF hospital & school campu...      within an hour
# 4  I'm an Interior Stylist living in SF. \r\n\r\n...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  99%                 t
# 1                90%                  82%                 f
# 2               100%                  86%                 t
# 3               100%                  86%                 t
# 4               100%                  43%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/efdad...
# 1  https://a0.muscache.com/im/users/8904/profile_...
# 2  https://a0.muscache.com/im/users/21994/profile...
# 3  https://a0.muscache.com/im/users/21994/profile...
# 4  https://a0.muscache.com/im/pictures/user/6e05b...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/efdad...    Duboce Triangle
# 1  https://a0.muscache.com/im/users/8904/profile_...     Bernal Heights
# 2  https://a0.muscache.com/im/users/21994/profile...        Cole Valley
# 3  https://a0.muscache.com/im/users/21994/profile...        Cole Valley
# 4  https://a0.muscache.com/im/pictures/user/6e05b...       Alamo Square
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    2                          2
# 2                   10                         10
# 3                   10                         10
# 4                    2                          2
#
#                                   host_verifications host_has_profile_pic  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1  ['email', 'phone', 'reviews', 'kba', 'work_ema...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                            street   neighbourhood  \
# 0                      t  San Francisco, CA, United States    Lower Haight
# 1                      t  San Francisco, CA, United States  Bernal Heights
# 2                      t  San Francisco, CA, United States     Cole Valley
# 3                      t  San Francisco, CA, United States     Cole Valley
# 4                      t  San Francisco, CA, United States    Alamo Square
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed           city state  \
# 0       Western Addition                           NaN  San Francisco    CA
# 1         Bernal Heights                           NaN  San Francisco    CA
# 2         Haight Ashbury                           NaN  San Francisco    CA
# 3         Haight Ashbury                           NaN  San Francisco    CA
# 4       Western Addition                           NaN  San Francisco    CA
#
#   zipcode         market     smart_location country_code        country  \
# 0   94117  San Francisco  San Francisco, CA           US  United States
# 1   94110  San Francisco  San Francisco, CA           US  United States
# 2   94117  San Francisco  San Francisco, CA           US  United States
# 3   94117  San Francisco  San Francisco, CA           US  United States
# 4   94117  San Francisco  San Francisco, CA           US  United States
#
#    latitude  longitude is_location_exact property_type        room_type  \
# 0  37.76931 -122.43386                 t     Apartment  Entire home/apt
# 1  37.74511 -122.42102                 t     Apartment  Entire home/apt
# 2  37.76669 -122.45250                 t     Apartment     Private room
# 3  37.76487 -122.45183                 t     Apartment     Private room
# 4  37.77525 -122.43637                 t   Condominium  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             3        1.0       1.0   2.0  Real Bed
# 1             5        1.0       2.0   3.0  Real Bed
# 2             2        4.0       1.0   1.0  Real Bed
# 3             2        4.0       1.0   1.0  Real Bed
# 4             4        1.5       2.0   2.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...          NaN  $170.00
# 1  {Internet,Wifi,Kitchen,Heating,"Family/kid fri...          NaN  $235.00
# 2  {TV,Internet,Wifi,Kitchen,"Free street parking...          NaN   $65.00
# 3  {TV,Internet,Wifi,Kitchen,"Free street parking...          NaN   $65.00
# 4  {TV,Internet,Wifi,Kitchen,"Free street parking...          NaN  $741.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0    $1,120.00     $4,200.00          $100.00      $100.00                2
# 1    $1,600.00     $5,500.00              NaN      $100.00                2
# 2      $485.00     $1,685.00          $200.00       $50.00                1
# 3      $490.00     $1,685.00          $200.00       $50.00                1
# 4          NaN           NaN            $0.00      $175.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $25.00               1              30                       1
# 1        $0.00              30              60                      30
# 2       $12.00              32              60                      32
# 3       $12.00              32              90                      32
# 4      $199.00               5             111                       5
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       1                      30                      30
# 1                      30                      60                      60
# 2                      32                      60                      60
# 3                      32                      90                      90
# 4                       5                     111                     111
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     1.0                    30.0      2 weeks ago
# 1                    30.0                    60.0     2 months ago
# 2                    32.0                    60.0     3 months ago
# 3                    32.0                    90.0     7 months ago
# 4                     5.0                   111.0     2 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                3                5                8
# 1                t                0                0                0
# 2                t                7               37               67
# 3                t               30               60               90
# 4                t               30               60               90
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                54            2020-02-12                233
# 1                 0            2020-02-12                111
# 2               342            2020-02-12                 18
# 3               365            2020-02-12                  8
# 4               365            2020-02-12                 28
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                     54   2009-07-23  2020-01-05                  97.0
# 1                      0   2009-05-03  2017-08-06                  98.0
# 2                      1   2009-08-31  2019-09-10                  86.0
# 3                      0   2014-09-08  2018-09-12                  93.0
# 4                      1   2009-09-25  2019-06-28                  97.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                     8.0                        8.0                    9.0
# 3                     9.0                        9.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                    10.0                  9.0
# 2                          9.0                     9.0                  8.0
# 3                         10.0                     9.0                  9.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license      license jurisdiction_names instant_bookable  \
# 0                t  STR-0001256  {"SAN FRANCISCO"}                t
# 1                t          NaN  {"SAN FRANCISCO"}                f
# 2                t          NaN  {"SAN FRANCISCO"}                f
# 3                t          NaN  {"SAN FRANCISCO"}                f
# 4                t  STR-0000264  {"SAN FRANCISCO"}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     moderate
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               9
# 3                               9
# 4                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             9
# 3                                             9
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.81
# 1                                            0               0.85
# 2                                            0               0.14
# 3                                            0               0.12
# 4                                            0               0.22

# %%
np.sum(listing.isnull(), axis=0)
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               0
# summary                                          220
# space                                           1297
# description                                       54
# experiences_offered                                0
# neighborhood_overview                           2259
# notes                                           3424
# transit                                         2709
# access                                          3388
# interaction                                     2835
# house_rules                                     2370
# thumbnail_url                                   8587
# medium_url                                      8587
# picture_url                                        0
# xl_picture_url                                  8587
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      5
# host_about                                      2089
# host_response_time                              1178
# host_response_rate                              1178
# host_acceptance_rate                             525
# host_is_superhost                                  0
# host_thumbnail_url                                 0
# host_picture_url                                   0
# host_neighbourhood                               527
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# host_has_profile_pic                               0
# host_identity_verified                             0
# street                                             0
# neighbourhood                                     12
# neighbourhood_cleansed                             0
# neighbourhood_group_cleansed                    8587
# city                                               0
# state                                              6
# zipcode                                           24
# market                                            21
# smart_location                                     0
# country_code                                       0
# country                                            0
# latitude                                           0
# longitude                                          0
# is_location_exact                                  0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                          6
# bedrooms                                           3
# beds                                              26
# bed_type                                           0
# amenities                                          0
# square_feet                                     8455
# price                                              0
# weekly_price                                    7542
# monthly_price                                   7569
# security_deposit                                1751
# cleaning_fee                                     942
# guests_included                                    0
# extra_people                                       0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# maximum_minimum_nights                             0
# minimum_maximum_nights                             0
# maximum_maximum_nights                             0
# minimum_nights_avg_ntm                             0
# maximum_nights_avg_ntm                             0
# calendar_updated                                   0
# has_availability                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# calendar_last_scraped                              0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# first_review                                    1991
# last_review                                     1991
# review_scores_rating                            2040
# review_scores_accuracy                          2048
# review_scores_cleanliness                       2048
# review_scores_checkin                           2049
# review_scores_communication                     2047
# review_scores_location                          2049
# review_scores_value                             2049
# requires_license                                   0
# license                                         3343
# jurisdiction_names                                51
# instant_bookable                                   0
# is_business_travel_ready                           0
# cancellation_policy                                0
# require_guest_profile_picture                      0
# require_guest_phone_verification                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1991
# dtype: int64

# %% [markdown]
# https://rstudio-pubs-static.s3.amazonaws.com/407929_afc5ef0f2ad648389447a6ca3f4a7cd4.html <br>
# Based on the suggestion and our exploration, the first model will use below columns. <br>
# The business context is -> We want to make the pricing suggestion for the user.

# %%
used_columns_numerical = ['host_since', 'host_location', 'host_is_superhost', 'host_has_profile_pic',
                          'host_identity_verified', 'host_response_time', 'host_response_rate',
                          'host_acceptance_rate', 'neighbourhood_cleansed', 'property_type', 'room_type',
                          'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities',
                          'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
                          'number_of_reviews', 'review_scores_accuracy', 'review_scores_cleanliness',
                          'review_scores_checkin', 'review_scores_communication', 'review_scores_location',
                          'review_scores_value', 'cancellation_policy', 'require_guest_profile_picture',
                          'require_guest_phone_verification', 'calculated_host_listings_count']
used_columns_text = ['summary', 'description']
y = ['price']

# %%
len(used_columns_numerical)
# Out:
# 33

# %% [markdown]
# For we want to make the dataset static at the first place. i.e. after we add variable, we won't change the total # of data because of None value or etc.

# %%
listing_final = listing[used_columns_numerical + used_columns_text + y].dropna(how='any')

# %%
listing_final.shape
# Out:
# (4579, 36)

# %% [markdown]
# # Fit with numerical information

# %%
listing_numerical = listing_final[used_columns_numerical]

# %%
listing_numerical.head(3)
# Out:
#    host_since                             host_location host_is_superhost  \
# 0  2008-07-31  San Francisco, California, United States                 t
# 2  2009-06-17  San Francisco, California, United States                 t
# 3  2009-06-17  San Francisco, California, United States                 t
#
#   host_has_profile_pic host_identity_verified host_response_time  \
# 0                    t                      t     within an hour
# 2                    t                      t     within an hour
# 3                    t                      t     within an hour
#
#   host_response_rate host_acceptance_rate neighbourhood_cleansed  \
# 0               100%                  99%       Western Addition
# 2               100%                  86%         Haight Ashbury
# 3               100%                  86%         Haight Ashbury
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0     Apartment  Entire home/apt             3        1.0       1.0   2.0
# 2     Apartment     Private room             2        4.0       1.0   1.0
# 3     Apartment     Private room             2        4.0       1.0   1.0
#
#    bed_type                                          amenities  \
# 0  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...
# 2  Real Bed  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 3  Real Bed  {TV,Internet,Wifi,Kitchen,"Free street parking...
#
#   security_deposit cleaning_fee  guests_included extra_people  minimum_nights  \
# 0          $100.00      $100.00                2       $25.00               1
# 2          $200.00       $50.00                1       $12.00              32
# 3          $200.00       $50.00                1       $12.00              32
#
#    number_of_reviews  review_scores_accuracy  review_scores_cleanliness  \
# 0                233                    10.0                       10.0
# 2                 18                     8.0                        8.0
# 3                  8                     9.0                        9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 2                    9.0                          9.0                     9.0
# 3                   10.0                         10.0                     9.0
#
#    review_scores_value          cancellation_policy  \
# 0                  9.0                     moderate
# 2                  8.0  strict_14_with_grace_period
# 3                  9.0  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 2                             f                                f
# 3                             f                                f
#
#    calculated_host_listings_count
# 0                               1
# 2                               9
# 3                               9

# %% [markdown]
# ### Data preprocessing

# %%
listing_numerical = listing_final[used_columns_numerical]
one_hot_columns = ['host_response_time', 'neighbourhood_cleansed', 'property_type', 'room_type',
                   'bed_type', 'cancellation_policy']
count_columns = ['amenities']
listing_numerical = pd.get_dummies(listing_numerical, columns=one_hot_columns, drop_first=True)
listing_numerical['amenities'] = listing_numerical.apply(lambda row: len(row.amenities.split(',')),
                                                         axis=1)
listing_numerical['host_location'] = listing_numerical.apply(lambda row: True if row.host_location == 'San Francisco, California, United States' else False,
                                                                 axis=1)
listing_numerical['host_is_superhost'] = listing_numerical.apply(lambda row: True if row.host_is_superhost == 't' else False,
                                                                 axis=1)
listing_numerical['host_has_profile_pic'] = listing_numerical.apply(lambda row: True if row.host_has_profile_pic == 't' else False,
                                                                 axis=1)
listing_numerical['host_identity_verified'] = listing_numerical.apply(lambda row: True if row.host_identity_verified == 't' else False,
                                                                 axis=1)
listing_numerical['host_response_rate'] = listing_numerical.apply(lambda row: float(row.host_response_rate.strip('%')),
                                                                 axis=1)
listing_numerical['host_acceptance_rate'] = listing_numerical.apply(lambda row: float(row.host_acceptance_rate.strip('%')),
                                                                 axis=1)
listing_numerical['security_deposit'] = listing_numerical.apply(lambda row: float(row.security_deposit.strip('$').replace(',', '')),
                                                                 axis=1)
listing_numerical['cleaning_fee'] = listing_numerical.apply(lambda row: float(row.cleaning_fee.strip('$').replace(',', '')),
                                                                 axis=1)
listing_numerical['extra_people'] = listing_numerical.apply(lambda row: float(row.extra_people.strip('$').replace(',', '')),
                                                                 axis=1)
listing_numerical['require_guest_profile_picture'] = listing_numerical.apply(lambda row: True if row.require_guest_profile_picture == 't' else False,
                                                                 axis=1)
listing_numerical['require_guest_phone_verification'] = listing_numerical.apply(lambda row: True if row.require_guest_phone_verification == 't' else False,
                                                                 axis=1)
listing_numerical['host_since'] = listing_numerical.apply(lambda row: datetime.strptime(row.host_since, '%Y-%m-%d'),
                                                          axis=1)
listing_numerical['host_since'] = pd.DatetimeIndex(listing_numerical['host_since']).astype(np.int64) // 10 ** 9

y = listing_final.apply(lambda row: float(row.price.strip('$').replace(',', '')),axis=1)

# %%
listing_numerical.head(3)
# Out:
#    host_since  host_location  host_is_superhost  host_has_profile_pic  \
# 0  1217462400           True               True                  True
# 2  1245196800           True               True                  True
# 3  1245196800           True               True                  True
#
#    host_identity_verified  host_response_rate  host_acceptance_rate  \
# 0                    True               100.0                  99.0
# 2                    True               100.0                  86.0
# 3                    True               100.0                  86.0
#
#    accommodates  bathrooms  bedrooms  beds  amenities  security_deposit  \
# 0             3        1.0       1.0   2.0         34             100.0
# 2             2        4.0       1.0   1.0         18             200.0
# 3             2        4.0       1.0   1.0         16             200.0
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0         100.0                2          25.0               1
# 2          50.0                1          12.0              32
# 3          50.0                1          12.0              32
#
#    number_of_reviews  review_scores_accuracy  review_scores_cleanliness  \
# 0                233                    10.0                       10.0
# 2                 18                     8.0                        8.0
# 3                  8                     9.0                        9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 2                    9.0                          9.0                     9.0
# 3                   10.0                         10.0                     9.0
#
#    review_scores_value  require_guest_profile_picture  \
# 0                  9.0                          False
# 2                  8.0                          False
# 3                  9.0                          False
#
#    require_guest_phone_verification  calculated_host_listings_count  \
# 0                             False                               1
# 2                             False                               9
# 3                             False                               9
#
#    host_response_time_within a day  host_response_time_within a few hours  \
# 0                                0                                      0
# 2                                0                                      0
# 3                                0                                      0
#
#    host_response_time_within an hour  neighbourhood_cleansed_Bernal Heights  \
# 0                                  1                                      0
# 2                                  1                                      0
# 3                                  1                                      0
#
#    neighbourhood_cleansed_Castro/Upper Market  \
# 0                                           0
# 2                                           0
# 3                                           0
#
#    neighbourhood_cleansed_Chinatown  neighbourhood_cleansed_Crocker Amazon  \
# 0                                 0                                      0
# 2                                 0                                      0
# 3                                 0                                      0
#
#    neighbourhood_cleansed_Diamond Heights  \
# 0                                       0
# 2                                       0
# 3                                       0
#
#    neighbourhood_cleansed_Downtown/Civic Center  \
# 0                                             0
# 2                                             0
# 3                                             0
#
#    neighbourhood_cleansed_Excelsior  \
# 0                                 0
# 2                                 0
# 3                                 0
#
#    neighbourhood_cleansed_Financial District  \
# 0                                          0
# 2                                          0
# 3                                          0
#
#    neighbourhood_cleansed_Glen Park  neighbourhood_cleansed_Golden Gate Park  \
# 0                                 0                                        0
# 2                                 0                                        0
# 3                                 0                                        0
#
#    neighbourhood_cleansed_Haight Ashbury  \
# 0                                      0
# 2                                      1
# 3                                      1
#
#    neighbourhood_cleansed_Inner Richmond  neighbourhood_cleansed_Inner Sunset  \
# 0                                      0                                    0
# 2                                      0                                    0
# 3                                      0                                    0
#
#    neighbourhood_cleansed_Lakeshore  neighbourhood_cleansed_Marina  \
# 0                                 0                              0
# 2                                 0                              0
# 3                                 0                              0
#
#    neighbourhood_cleansed_Mission  neighbourhood_cleansed_Nob Hill  \
# 0                               0                                0
# 2                               0                                0
# 3                               0                                0
#
#    neighbourhood_cleansed_Noe Valley  neighbourhood_cleansed_North Beach  \
# 0                                  0                                   0
# 2                                  0                                   0
# 3                                  0                                   0
#
#    neighbourhood_cleansed_Ocean View  neighbourhood_cleansed_Outer Mission  \
# 0                                  0                                     0
# 2                                  0                                     0
# 3                                  0                                     0
#
#    neighbourhood_cleansed_Outer Richmond  neighbourhood_cleansed_Outer Sunset  \
# 0                                      0                                    0
# 2                                      0                                    0
# 3                                      0                                    0
#
#    neighbourhood_cleansed_Pacific Heights  neighbourhood_cleansed_Parkside  \
# 0                                       0                                0
# 2                                       0                                0
# 3                                       0                                0
#
#    neighbourhood_cleansed_Potrero Hill  \
# 0                                    0
# 2                                    0
# 3                                    0
#
#    neighbourhood_cleansed_Presidio Heights  \
# 0                                        0
# 2                                        0
# 3                                        0
#
#    neighbourhood_cleansed_Russian Hill  neighbourhood_cleansed_Seacliff  \
# 0                                    0                                0
# 2                                    0                                0
# 3                                    0                                0
#
#    neighbourhood_cleansed_South of Market  neighbourhood_cleansed_Twin Peaks  \
# 0                                       0                                  0
# 2                                       0                                  0
# 3                                       0                                  0
#
#    neighbourhood_cleansed_Visitacion Valley  \
# 0                                         0
# 2                                         0
# 3                                         0
#
#    neighbourhood_cleansed_West of Twin Peaks  \
# 0                                          0
# 2                                          0
# 3                                          0
#
#    neighbourhood_cleansed_Western Addition  property_type_Apartment  \
# 0                                        1                        1
# 2                                        0                        1
# 3                                        0                        1
#
#    property_type_Bed and breakfast  property_type_Boutique hotel  \
# 0                                0                             0
# 2                                0                             0
# 3                                0                             0
#
#    property_type_Bungalow  property_type_Cabin  property_type_Castle  \
# 0                       0                    0                     0
# 2                       0                    0                     0
# 3                       0                    0                     0
#
#    property_type_Condominium  property_type_Cottage  \
# 0                          0                      0
# 2                          0                      0
# 3                          0                      0
#
#    property_type_Earth house  property_type_Guest suite  \
# 0                          0                          0
# 2                          0                          0
# 3                          0                          0
#
#    property_type_Guesthouse  property_type_Hostel  property_type_Hotel  \
# 0                         0                     0                    0
# 2                         0                     0                    0
# 3                         0                     0                    0
#
#    property_type_House  property_type_Loft  property_type_Other  \
# 0                    0                   0                    0
# 2                    0                   0                    0
# 3                    0                   0                    0
#
#    property_type_Resort  property_type_Serviced apartment  \
# 0                     0                                 0
# 2                     0                                 0
# 3                     0                                 0
#
#    property_type_Tiny house  property_type_Townhouse  property_type_Villa  \
# 0                         0                        0                    0
# 2                         0                        0                    0
# 3                         0                        0                    0
#
#    room_type_Hotel room  room_type_Private room  room_type_Shared room  \
# 0                     0                       0                      0
# 2                     0                       1                      0
# 3                     0                       1                      0
#
#    bed_type_Couch  bed_type_Futon  bed_type_Pull-out Sofa  bed_type_Real Bed  \
# 0               0               0                       0                  1
# 2               0               0                       0                  1
# 3               0               0                       0                  1
#
#    cancellation_policy_moderate  cancellation_policy_strict  \
# 0                             1                           0
# 2                             0                           0
# 3                             0                           0
#
#    cancellation_policy_strict_14_with_grace_period  \
# 0                                                0
# 2                                                1
# 3                                                1
#
#    cancellation_policy_super_strict_30  cancellation_policy_super_strict_60
# 0                                    0                                    0
# 2                                    0                                    0
# 3                                    0                                    0

# %%
listing_numerical.shape
# Out:
# (4579, 97)

# %% [markdown]
# ### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(listing_numerical, y,
                                                    test_size=0.2, random_state=42)

# %% [markdown]
# ### Fit Lasso

# %%
def print_metric(X_train, X_test, y_train, y_test, estimator):
    print('In sample R-squared: ', r2_score(y_train, estimator.predict(X_train)))
    print('Out of sample R-squared: ', r2_score(y_test, estimator.predict(X_test)))
    print('In sample MSE: ', mean_squared_error(y_train, estimator.predict(X_train)))
    print('Out of sample MSE: ', mean_squared_error(y_test, estimator.predict(X_test)))

# %%
lasso = LassoCV(normalize=True)

# %%
lasso.fit(X_train, y_train)
# Out:
# LassoCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=True,
#         positive=False, precompute='auto', random_state=None,
#         selection='cyclic', tol=0.0001, verbose=False)

# %%
print_metric(X_train, X_test, y_train, y_test, lasso)
# Out:
# In sample R-squared:  0.5260578471827375
# Out of sample R-squared:  0.5848867267023228
# In sample MSE:  19727.94457860417
# Out of sample MSE:  15514.789632359389

# %%
coef = lasso.coef_[np.abs(lasso.coef_) > 10e-1]
# make importances relative to max importance
sorted_idx = np.argsort(coef)
pos = np.arange(sorted_idx.shape[0])
plt.figure(figsize=(12, 24))
plt.barh(pos, coef[sorted_idx], height=0.8, align='center')
plt.yticks(pos, listing_numerical.columns[np.abs(lasso.coef_) > 10e-1][sorted_idx])
plt.xlabel('Coefficient')
plt.title('Variable coefficient value')
plt.tight_layout()
plt.savefig('Lasso.png', bbox='tight')
plt.show()

# %% [markdown]
# ### Fit with gradient boosting machine

# %%
params = {'n_estimators': 500, 'max_depth': 3, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls', 'n_iter_no_change': 3, 'random_state':42}
clf = GradientBoostingRegressor(**params)

# %%
clf.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.01, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=3, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
print_metric(X_train, X_test, y_train, y_test, clf)
# Out:
# In sample R-squared:  0.6750594935271641
# Out of sample R-squared:  0.6279412084829636
# In sample MSE:  13525.718834955225
# Out of sample MSE:  13905.6355278654

# %%
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())
feature_importance = feature_importance[feature_importance > 0.5]
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.figure(figsize=(12, 18))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, listing_numerical.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# ### Train the model with data filtered based on review_score_value

# %%
sns.barplot(x=X_train.review_scores_value.value_counts().keys(),
            y=X_train.review_scores_value.value_counts().values)

# %%
params = {'n_estimators': 500, 'max_depth': 3, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls', 'n_iter_no_change': 3, 'random_state':42}
clf_non_filter = GradientBoostingRegressor(**params)
clf_filtered = GradientBoostingRegressor(**params)
clf_non_filter.fit(X_train, y_train)
clf_filtered.fit(X_train[X_train.review_scores_value == 10], y_train[X_train[X_train.review_scores_value == 10].index])
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.01, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=3, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
non_filter_price = clf_non_filter.predict(X_test)
filtered_price = clf_filtered.predict(X_test)
plt.figure(figsize=(12, 8))
sns.distplot(non_filter_price, hist=False, label='non_filter_prediction')
sns.distplot(filtered_price, hist=False, label='filtered_prediction')
plt.legend()
plt.show()

# %% [markdown]
# #### If we assume those units which review_score_value have 10 scores are all 'good pricing', then the conclusion is: this optimal pricing model will predict the price to be lower and more centralized.

# %% [markdown]
# ### Is summary affecting the performance of model? -> NO

# %%
corpus = listing['summary'].dropna().tolist() + listing['description'].dropna().tolist()
corpus = [text.split(' ') for text in corpus]
model = Word2Vec(corpus, size=300, window=5, min_count=1, workers=4)

# %%
wv_dict = {}
for ind, text in zip(listing_final.index, listing_final.description):
    wv_dict[ind] = np.mean([model.wv[voc] if voc in model.wv else 0 for voc in text], axis=0)

# %%
listing_full = pd.concat([listing_numerical, pd.DataFrame(wv_dict).transpose()], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(listing_full, y,
                                                    test_size=0.2, random_state=42)

# %%
lasso = LassoCV(normalize=True)
lasso.fit(X_train, y_train)
print_metric(X_train, X_test, y_train, y_test, lasso)
# Out:
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23408.705243214965, tolerance: 12488.39274679181
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24329.704330205917, tolerance: 12488.39274679181
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15935.90831360966, tolerance: 12488.39274679181
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49738.36159390956, tolerance: 12488.39274679181
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22385.889654912055, tolerance: 12488.39274679181
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22358.06022130698, tolerance: 12488.39274679181
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36541.96999690682, tolerance: 12488.39274679181
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56515.40871762484, tolerance: 12950.661917576792
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136143.63992469013, tolerance: 12950.661917576792
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91985.05707450211, tolerance: 12950.661917576792
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73307.2368561551, tolerance: 12950.661917576792
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72210.2870484814, tolerance: 12950.661917576792
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30607.748536147177, tolerance: 11762.080393208189
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39038.69732156396, tolerance: 11762.080393208189
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37911.99196448922, tolerance: 11762.080393208189
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46643.08649107069, tolerance: 11762.080393208189
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24686.530126586556, tolerance: 11568.767237529853
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13980.385868951678, tolerance: 11568.767237529853
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29033.769011497498, tolerance: 11568.767237529853
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43605.01747339219, tolerance: 11568.767237529853
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109577.14221385866, tolerance: 11568.767237529853
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47587.214518383145, tolerance: 11568.767237529853
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40459.742374293506, tolerance: 11568.767237529853
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22524.94055364281, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14257.457939185202, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26001.471133694053, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13905.029417842627, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21420.986882559955, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50241.60418780893, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27897.328875005245, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# /Users/wangyaoting/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83005.5179483369, tolerance: 12215.963375844423
#   tol, rng, random, positive)
# In sample R-squared:  0.5248528222547045
# Out of sample R-squared:  0.5838405931930899
# In sample MSE:  19778.104001763215
# Out of sample MSE:  15553.88869848699

# %%
params = {'n_estimators': 500, 'max_depth': 3, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls', 'n_iter_no_change': 3}
clf = GradientBoostingRegressor(**params)
clf.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.01, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=3, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
print_metric(X_train, X_test, y_train, y_test, clf)
# Out:
# In sample R-squared:  0.6086514040617359
# Out of sample R-squared:  0.5742036815365257
# In sample MSE:  16289.969916563676
# Out of sample MSE:  15914.066670801574
